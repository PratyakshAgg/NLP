# %% [markdown]
# # Assignment-2a

# %%
import nltk

# %%
from nltk.corpus import *

# %%
# In the news genre of brown corpus, find the count of the words starting with wh, such as what, when, where, who and why?
print(brown.categories())
# Out:
# ['adventure', 'belles_lettres', 'editorial', 'fiction', 'government', 'hobbies', 'humor', 'learned', 'lore', 'mystery', 'news', 'religion', 'reviews', 'romance', 'science_fiction']

# %%
news_data=brown.words(categories='news')
news_data
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
print(len([w for w in news_data if w.startswith('wh')]))
# Out:
# 932

# %%
# Find the conditional frequency distribution of modals ['can', 'could', 'may', 'might', 'must', 'will']
# in all the categories of brown corpus?
modals = ['can', 'could', 'may', 'might', 'must', 'will']
cat = brown.categories()

# %%
for category in cat:
    words = brown.words(categories=category)
    fdist = nltk.FreqDist([w.lower() for w in words])
    for modal in modals:
        print(modal, fdist[modal], category)
# Out:
# can 48 adventure
# could 154 adventure
# may 7 adventure
# might 59 adventure
# must 27 adventure
# will 51 adventure
# can 249 belles_lettres
# could 216 belles_lettres
# may 221 belles_lettres
# might 113 belles_lettres
# must 171 belles_lettres
# will 246 belles_lettres
# can 124 editorial
# could 57 editorial
# may 79 editorial
# might 39 editorial
# must 55 editorial
# will 235 editorial
# can 39 fiction
# could 168 fiction
# may 10 fiction
# might 44 fiction
# must 55 fiction
# will 56 fiction
# can 119 government
# could 38 government
# may 179 government
# might 13 government
# must 102 government
# will 244 government
# can 276 hobbies
# could 59 hobbies
# may 143 hobbies
# might 22 hobbies
# must 84 hobbies
# will 269 hobbies
# can 17 humor
# could 33 humor
# may 8 humor
# might 8 humor
# must 9 humor
# will 13 humor
# can 367 learned
# could 159 learned
# may 336 learned
# might 128 learned
# must 203 learned
# will 340 learned
# can 170 lore
# could 142 lore
# ...

# %%
# Find the year out of the filenames in the Inaugural Address Corpus?
inaugural.fileids()
# Out:
# ['1789-Washington.txt',
#  '1793-Washington.txt',
#  '1797-Adams.txt',
#  '1801-Jefferson.txt',
#  '1805-Jefferson.txt',
#  '1809-Madison.txt',
#  '1813-Madison.txt',
#  '1817-Monroe.txt',
#  '1821-Monroe.txt',
#  '1825-Adams.txt',
#  '1829-Jackson.txt',
#  '1833-Jackson.txt',
#  '1837-VanBuren.txt',
#  '1841-Harrison.txt',
#  '1845-Polk.txt',
#  '1849-Taylor.txt',
#  '1853-Pierce.txt',
#  '1857-Buchanan.txt',
#  '1861-Lincoln.txt',
#  '1865-Lincoln.txt',
#  '1869-Grant.txt',
#  '1873-Grant.txt',
#  '1877-Hayes.txt',
#  '1881-Garfield.txt',
#  '1885-Cleveland.txt',
#  '1889-Harrison.txt',
#  '1893-Cleveland.txt',
#  '1897-McKinley.txt',
#  '1901-McKinley.txt',
#  '1905-Roosevelt.txt',
#  '1909-Taft.txt',
#  '1913-Wilson.txt',
#  '1917-Wilson.txt',
#  '1921-Harding.txt',
#  '1925-Coolidge.txt',
#  '1929-Hoover.txt',
#  '1933-Roosevelt.txt',
#  '1937-Roosevelt.txt',
#  '1941-Roosevelt.txt',
#  '1945-Roosevelt.txt',
#  '1949-Truman.txt',
#  '1953-Eisenhower.txt',
# ...

# %%
[fileid[:4] for fileid in inaugural.fileids()]
# Out:
# ['1789',
#  '1793',
#  '1797',
#  '1801',
#  '1805',
#  '1809',
#  '1813',
#  '1817',
#  '1821',
#  '1825',
#  '1829',
#  '1833',
#  '1837',
#  '1841',
#  '1845',
#  '1849',
#  '1853',
#  '1857',
#  '1861',
#  '1865',
#  '1869',
#  '1873',
#  '1877',
#  '1881',
#  '1885',
#  '1889',
#  '1893',
#  '1897',
#  '1901',
#  '1905',
#  '1909',
#  '1913',
#  '1917',
#  '1921',
#  '1925',
#  '1929',
#  '1933',
#  '1937',
#  '1941',
#  '1945',
#  '1949',
#  '1953',
#  '1957',
#  '1961',
#  '1965',
#  '1969',
#  '1973',
#  '1977',
#  '1981',
#  '1985',
#  '1989',
#  '1993',
#  '1997',
#  '2001',
#  '2005',
#  '2009',
#  '2013',
#  '2017',
#  '2021']

# %%
# Read in the texts of the State of the Union addresses, using the state_union corpus reader.
# Count occurrences of men , women , and people in each document. What has happened to the usage
# of these words over time?
files = state_union.fileids()
files
# Out:
# ['1945-Truman.txt',
#  '1946-Truman.txt',
#  '1947-Truman.txt',
#  '1948-Truman.txt',
#  '1949-Truman.txt',
#  '1950-Truman.txt',
#  '1951-Truman.txt',
#  '1953-Eisenhower.txt',
#  '1954-Eisenhower.txt',
#  '1955-Eisenhower.txt',
#  '1956-Eisenhower.txt',
#  '1957-Eisenhower.txt',
#  '1958-Eisenhower.txt',
#  '1959-Eisenhower.txt',
#  '1960-Eisenhower.txt',
#  '1961-Kennedy.txt',
#  '1962-Kennedy.txt',
#  '1963-Johnson.txt',
#  '1963-Kennedy.txt',
#  '1964-Johnson.txt',
#  '1965-Johnson-1.txt',
#  '1965-Johnson-2.txt',
#  '1966-Johnson.txt',
#  '1967-Johnson.txt',
#  '1968-Johnson.txt',
#  '1969-Johnson.txt',
#  '1970-Nixon.txt',
#  '1971-Nixon.txt',
#  '1972-Nixon.txt',
#  '1973-Nixon.txt',
#  '1974-Nixon.txt',
#  '1975-Ford.txt',
#  '1976-Ford.txt',
#  '1977-Ford.txt',
#  '1978-Carter.txt',
#  '1979-Carter.txt',
#  '1980-Carter.txt',
#  '1981-Reagan.txt',
#  '1982-Reagan.txt',
#  '1983-Reagan.txt',
#  '1984-Reagan.txt',
#  '1985-Reagan.txt',
#  '1986-Reagan.txt',
# ...

# %%
cfd = nltk.ConditionalFreqDist(
  (target, fileid[:4])
  for fileid in state_union.fileids()
  for w in state_union.words(fileid)
  for target in ['men', 'women', 'people']
  if w.lower().startswith(target))

cfd.plot()
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
# Pick a pair of texts and study the differences between them, in terms of vocabulary, vocabulary richness, genre, etc.
news_data=brown.words(categories='news')
religion_data=brown.words(categories='religion')

# %%
news_data = nltk.Text(news_data)
religion_data = nltk.Text(religion_data)

# %%
#trying to find common words
news_fd = nltk.FreqDist(news_data)
religion_fd = nltk.FreqDist(religion_data)
print(news_data.concordance('state'))
print(religion_data.concordance('state'))
# Out:
# Displaying 25 of 153 matches:
# . The grand jury took a swipe at the State Welfare Department's handling of fed
# program '' , the jury said , but the State Welfare Department `` has seen fit t
# partments of all the counties in the state with the exception of Fulton County
#  said Wednesday . Robert Snodgrass , state GOP chairman , said a meeting held T
# iastic responses from the audience . State Party Chairman James W. Dorsey added
# that enthusiasm was picking up for a state rally to be held Sept. 8 in Savannah
#  Republicans would have to face is a state law which says that before making a
# ses in its platform . Sam Caldwell , State Highway Department public relations
# bonds Meanwhile , it was learned the State Highway Department is very near bein
# onds . The bond issue will go to the state courts for a friendly test suit to t
# funds be received and expended '' as state funds . Barber , who is in his 13th
# ...

# %%
# Write a program to find all words that occur at least three times in the Brown Corpus.
all_unique_words_brown=set(brown.words())
all_unique_words_brown
# Out:
# {"Pollock's",
#  'manhood',
#  'Hair',
#  '1-degree',
#  'glowing',
#  'garde',
#  'bulls',
#  'kissing',
#  'cures',
#  'Words',
#  'ed.',
#  'Committeemen',
#  'essentially',
#  'best-looking',
#  'Da-da-da-dum',
#  'universities',
#  'deltoids',
#  'vandalism',
#  'neo-classicism',
#  'Gary',
#  '$172,400',
#  'dwarf',
#  'disciplining',
#  'subservience',
#  'higher',
#  'reject',
#  'comin',
#  'memorized',
#  'DTF',
#  'manuals',
#  'Chromspun',
#  'Existence',
#  'resulting',
#  'charters',
#  "Harley's",
#  'helion',
#  'Taft',
#  'storehouses',
#  'lobes',
#  'Considered',
#  'coexistent',
#  "Y'all",
#  'dismay',
#  'Kleenex',
#  'Lauritsen',
#  'develops',
#  'youngish',
#  'sterility',
#  'enemies',
#  'solar-radiation',
#  'confluent',
#  'baldness',
#  'Honshu',
#  'ham-radio',
#  'Forgiveness',
#  'contribs',
#  'drowsy',
#  'secularism',
#  'hors',
#  'Dienbienphu',
#  "1920's",
#  'avoidance',
#  'mesenteric',
#  'cackly',
#  'greatcoated',
#  '573',
#  'wiped',
# ...

# %%
brown_fd=nltk.FreqDist(brown.words())

# %%
atleast_3times=[word for word in all_unique_words_brown if brown_fd[word]>2]
print(atleast_3times)
# Out:
# ['manhood', 'glowing', 'kissing', 'cures', 'Words', 'Committeemen', 'essentially', 'universities', 'Gary', 'dwarf', 'higher', 'reject', 'comin', 'memorized', 'DTF', 'manuals', 'resulting', 'charters', 'lobes', "Y'all", 'dismay', 'develops', 'enemies', "1920's", 'avoidance', 'wiped', 'solo', 'cape', 'imposes', 'gusts', 'Communists', 'gather', 'Archbishop', 'Patterson', 'demography', 'triple', 'satellites', 'Okay', 'tame', 'Science', 'wake', 'dear', 'calmed', 'Grands', 'di-iodotyrosine', 'declarative', 'Although', 'promptly', 'tanks', 'DiMaggio', 'notorious', 'bracing', 'yards', 'speeding', 'delays', 'corporations', 'presented', 'cited', 'ceiling', 'convulsive', 'publisher', 'Renoir', 'latch', 'brackish', 'workable', 'confronting', "We'll", 'specifies', 'reproduction', 'fearing', 'Lonsdale', 'stink', 'symptomatic', 'reviewed', 'captivity', 'Sabella', 'destined', 'Fla.', 'haunt', 'disciplined', 'Phillips', 'debts', 'pleading', 'Breath', '$.03', 'charm', 'mid-September', 'attested', 'son
# ...

# %%
# Write a program to generate a table of lexical diversity scores (i.e., token/type ratios) for each
# genre. Include the full set of Brown Corpus genres ( nltk.corpus.brown.categories() ). Which genre
# has the lowest diversity

# %%
brown_categories=brown.categories()
print("Category, Tokens, Types, Lexical Diversity")
for category in brown_categories:
    category_words = brown.words(categories=category)
    print(category,len(category_words),len(set(category_words)),len(category_words)/(len(set(category_words))*1.0))
# Out:
# Category, Tokens, Types, Lexical Diversity
# adventure 69342 8874 7.814063556457065
# belles_lettres 173096 18421 9.396666847619565
# editorial 61604 9890 6.22891809908999
# fiction 68488 9302 7.362717695119329
# government 70117 8181 8.570712626818237
# hobbies 82345 11935 6.899455383326351
# humor 21695 5017 4.324297388877816
# learned 181888 16859 10.788777507562726
# lore 110299 14503 7.60525408536165
# mystery 57169 6982 8.188054998567745
# news 100554 14394 6.98582742809504
# religion 39399 6373 6.182174799937235
# reviews 40704 8626 4.718757245536749
# romance 70022 8452 8.284666351159489
# science_fiction 14470 3233 4.475719146303742

# %%
# Write a function that finds the 50 most frequently occurring words of a text?

# %%
from nltk.book import *

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
def freq_words(text):
    f = nltk.FreqDist(text)
    return f.most_common(50)

# %%
freq_words(text1)
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632),
#  ('as', 1620),
#  ('"', 1478),
#  ('all', 1462),
#  ('for', 1414),
#  ('this', 1280),
#  ('!', 1269),
#  ('at', 1231),
#  ('by', 1137),
#  ('but', 1113),
#  ('not', 1103),
#  ('--', 1070),
#  ('him', 1058),
#  ('from', 1052),
#  ('be', 1030),
#  ('on', 1005),
#  ('so', 918),
#  ('whale', 906),
#  ('one', 889),
#  ('you', 841),
#  ('had', 767),
#  ('have', 760),
#  ('there', 715),
#  ('But', 705),
#  ('or', 697),
#  ('were', 680),
#  ('now', 646),
#  ('which', 640),
#  ('?', 637),
#  ('me', 627),
#  ('like', 624)]

# %%
f = nltk.FreqDist(text1)
sorted_dict = sorted(f.items(), key=lambda x:x[1], reverse=True) 
converted_dict = dict(sorted_dict)
converted_dict
# Out:
# {',': 18713,
#  'the': 13721,
#  '.': 6862,
#  'of': 6536,
#  'and': 6024,
#  'a': 4569,
#  'to': 4542,
#  ';': 4072,
#  'in': 3916,
#  'that': 2982,
#  "'": 2684,
#  '-': 2552,
#  'his': 2459,
#  'it': 2209,
#  'I': 2124,
#  's': 1739,
#  'is': 1695,
#  'he': 1661,
#  'with': 1659,
#  'was': 1632,
#  'as': 1620,
#  '"': 1478,
#  'all': 1462,
#  'for': 1414,
#  'this': 1280,
#  '!': 1269,
#  'at': 1231,
#  'by': 1137,
#  'but': 1113,
#  'not': 1103,
#  '--': 1070,
#  'him': 1058,
#  'from': 1052,
#  'be': 1030,
#  'on': 1005,
#  'so': 918,
#  'whale': 906,
#  'one': 889,
#  'you': 841,
#  'had': 767,
#  'have': 760,
#  'there': 715,
#  'But': 705,
#  'or': 697,
#  'were': 680,
#  'now': 646,
#  'which': 640,
#  '?': 637,
#  'me': 627,
#  'like': 624,
#  'The': 612,
#  'their': 612,
#  'are': 586,
#  'they': 586,
#  'an': 582,
#  'some': 578,
#  'then': 571,
#  'my': 564,
#  'when': 553,
#  'upon': 538,
#  'out': 529,
#  'into': 520,
#  'man': 508,
#  'ship': 507,
#  'up': 505,
# ...
